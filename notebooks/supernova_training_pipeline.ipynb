# %% [markdown]
# # Supernova Visual Inspection Notebook
#
# Quick visual inspection of downloaded reference/science image pairs to:
# 1. Verify data quality
# 2. Identify same-mission pairs suitable for differencing
# 3. Visually spot supernovae in science images
# 4. Assess alignment/WCS quality
#
# **Data source:** `output/fits_training/` (organized from MAST downloads)

# %%
# Setup
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

print(f"Project root: {project_root}")
# Out:
# Project root: /mnt/astrid/AstrID

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, SymLogNorm
from astropy.io import fits
from astropy.wcs import WCS
from astropy.visualization import ZScaleInterval, ImageNormalize, AsinhStretch
import json
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore', category=fits.verify.VerifyWarning)

print("Imports complete")
# Out:
# Imports complete

# %%
# Configuration
TRAINING_DIR = project_root / "output" / "fits_training"
MANIFEST_FILE = TRAINING_DIR / "training_manifest.json"

# Load manifest
with open(MANIFEST_FILE) as f:
    manifest = json.load(f)

print(f"Training directory: {TRAINING_DIR}")
print(f"Total SNe in manifest: {len(manifest)}")
# Out:
# Training directory: /mnt/astrid/AstrID/output/fits_training
# Total SNe in manifest: 223

# %% [markdown]
# ## 1. Inventory: Same-Mission Pairs
#
# For meaningful image differencing, we need reference and science images from the **same mission** (ideally same filter too).

# %%
def get_mission_from_filename(filename: str) -> str:
    """Extract mission name from filename prefix."""
    name = Path(filename).name
    if name.startswith("SWIFT_"):
        return "SWIFT"
    elif name.startswith("PS1_"):
        return "PS1"
    elif name.startswith("GALEX_"):
        return "GALEX"
    elif name.startswith("TESS_"):
        return "TESS"
    else:
        return "UNKNOWN"

def get_swift_filter(filename: str) -> str:
    """Extract SWIFT UVOT filter from filename."""
    name = Path(filename).name.lower()
    for filt in ['uvw2', 'uvm2', 'uvw1', 'uuu', 'ubb', 'uvv', 'uwh']:
        if filt in name:
            return filt
    return "unknown"

def analyze_sn_missions(entry: dict) -> dict:
    """Analyze missions present in reference and science for one SN."""
    ref_missions = defaultdict(list)
    sci_missions = defaultdict(list)
    
    for f in entry.get('reference_files', []):
        mission = get_mission_from_filename(f)
        ref_missions[mission].append(f)
    
    for f in entry.get('science_files', []):
        mission = get_mission_from_filename(f)
        sci_missions[mission].append(f)
    
    # Find overlapping missions
    common_missions = set(ref_missions.keys()) & set(sci_missions.keys())
    
    return {
        'sn_name': entry['sn_name'],
        'ref_missions': dict(ref_missions),
        'sci_missions': dict(sci_missions),
        'common_missions': list(common_missions),
        'has_same_mission_pair': len(common_missions) > 0
    }

# Analyze all SNe
analyses = [analyze_sn_missions(entry) for entry in manifest]

# Summary
same_mission_sne = [a for a in analyses if a['has_same_mission_pair']]
cross_mission_sne = [a for a in analyses if not a['has_same_mission_pair']]

print("=" * 60)
print("MISSION ANALYSIS")
print("=" * 60)
print(f"\n✅ Same-mission pairs (usable for differencing): {len(same_mission_sne)}")
for a in same_mission_sne:
    print(f"   {a['sn_name']}: {', '.join(a['common_missions'])}")

print(f"\n⚠️  Cross-mission only (not ideal for differencing): {len(cross_mission_sne)}")
for a in cross_mission_sne:
    ref_m = list(a['ref_missions'].keys())
    sci_m = list(a['sci_missions'].keys())
    print(f"   {a['sn_name']}: REF={ref_m} vs SCI={sci_m}")
# Out:
# ============================================================
# MISSION ANALYSIS
# ============================================================
#
# ✅ Same-mission pairs (usable for differencing): 168
#    2005V: GALEX
#    2005ai: GALEX
#    2005ay: GALEX
#    2005az: GALEX
#    2005bj: GALEX
#    2005bk: GALEX
#    2005bn: GALEX
#    2005bt: GALEX
#    2005ca: GALEX
#    2005cc: GALEX
#    2005ck: GALEX
#    2005cr: GALEX
#    2005ct: GALEX
#    2005dh: GALEX
#    2005dn: GALEX
#    2005dq: GALEX
#    2005dt: GALEX
#    2005dy: GALEX
#    2005ea: GALEX
#    2005eb: GALEX
#    2005ej: GALEX
#    2005eu: GALEX
#    2005ev: GALEX
#    2005hh: GALEX
#    2005kl: GALEX
#    2005lt: GALEX
#    2005lx: GALEX
#    2005mf: GALEX
#    2005mr: GALEX
#    2005nc: SWIFT
#    2006P: GALEX
#    2006X: SWIFT
#    2006Z: GALEX
#    2006af: GALEX
#    2006ao: GALEX
#    2006aq: GALEX
#    2006as: GALEX
#    2006ax: GALEX
#    2006ay: GALEX
#    2006bk: GALEX
#    2006br: GALEX
#    2006bt: GALEX
#    2006by: GALEX
#    2006ce: GALEX
#    2006cg: GALEX
#    2006cj: GALEX
#    2006cs: GALEX
#    2006ct: GALEX
#    2006cx: GALEX
#    2006da: GALEX
#    2006db: GALEX
#    2006dg: GALEX
#    2006dh: GALEX
#    2006di: GALEX
#    2006dk: GALEX
#    2006do: GALEX
#    2006dq: GALEX
#    2006dw: GALEX
#    2006dy: GALEX
#    2006dz: GALEX
#    2006ec: GALEX
#    2006em: GALEX
#    2006et: SWIFT
#    2006gi: GALEX
#    2006gy: SWIFT
#    2006id: GALEX
#    2006je: GALEX
#    2006mo: GALEX
#    2006mr: SWIFT
#    2006ox: GALEX
#    2006qs: GALEX
#    2006qy: GALEX
#    2006rk: GALEX
#    2006rt: GALEX
#    2006ry: GALEX
#    2006ss: GALEX
#    2006st: GALEX
#    2006su: GALEX
#    2006tf: GALEX
#    2007ah: SWIFT
#    2007am: GALEX
#    2007ao: GALEX
#    2007aq: GALEX
#    2007au: GALEX
#    2007av: GALEX
#    2007bf: GALEX
#    2007bh: GALEX
#    2007cc: GALEX
#    2007ci: GALEX
#    2007cv: SWIFT
#    2007dd: GALEX
#    2007de: GALEX
#    2007dh: GALEX
#    2007du: GALEX
#    2007dw: GALEX
#    2007eo: GALEX
#    2007fy: GALEX
#    2007gr: GALEX
#    2007hb: GALEX
#    2007hd: GALEX
#    2007he: GALEX
#    2007is: GALEX
#    2007mq: GALEX
#    2007oc: SWIFT
#    2007qe: GALEX
#    2007rv: GALEX
#    2007va: GALEX
#    2008D: SWIFT
#    2008S: SWIFT
#    2008X: GALEX
#    2008bu: GALEX
#    2008ck: GALEX
#    2008dt: SWIFT
#    2008dx: SWIFT
#    2008fg: SWIFT
#    2008fh: SWIFT
#    2008fo: SWIFT
#    2008ij: SWIFT
#    2008ik: GALEX
#    2008iz: SWIFT
#    2009L: GALEX
#    2009Y: SWIFT
#    2009be: SWIFT
#    2009cb: GALEX
#    2009gf: SWIFT
#    2009hd: SWIFT
#    2009hk: PS1
#    2009hl: PS1
#    2009hz: PS1
#    2009ih: PS1
#    2009in: PS1
#    2009io: PS1
#    2009iu: GALEX
#    2009jf: SWIFT
#    2009jp: PS1
#    2009jq: PS1
#    2009ka: PS1
#    2009kc: PS1
#    2009kr: SWIFT
#    2009kw: PS1
#    2009ky: PS1
#    2009ld: PS1
#    2009le: PS1
#    2009lg: PS1
#    2009lo: PS1
#    2009lw: PS1
#    2009lz: PS1
#    2009mg: SWIFT
#    2009ml: PS1
#    2009nn: PS1
#    2009no: PS1
#    2009nr: PS1
#    2009nx: PS1
#    2009nz: SWIFT
#    2010G: PS1
#    2010N: PS1
#    2010R: PS1
#    2010bb: PS1
#    2010bc: PS1
#    HST05Dic: GALEX
#    HST05Fer: GALEX
#    HST05Gab: GALEX
#    HST05Koe: GALEX
#    HST05Lan: GALEX
#    HST05Red: GALEX
#    HST05Spo: GALEX
#    HST05Str: GALEX
#    HST05Zwi: GALEX
#
# ⚠️  Cross-mission only (not ideal for differencing): 55
#    2005at: REF=['GALEX'] vs SCI=['SWIFT']
#    2005cs: REF=['GALEX'] vs SCI=['SWIFT']
#    2005gl: REF=['GALEX'] vs SCI=['SWIFT']
#    2005ke: REF=['GALEX'] vs SCI=['SWIFT']
#    2005mz: REF=['GALEX'] vs SCI=['SWIFT']
#    2006Q: REF=['GALEX'] vs SCI=['SWIFT']
#    2006bz: REF=['SWIFT'] vs SCI=['GALEX']
#    2006dd: REF=['GALEX'] vs SCI=['SWIFT']
#    2007ax: REF=['GALEX'] vs SCI=['SWIFT']
#    2007cu: REF=['GALEX'] vs SCI=['SWIFT']
#    2007on: REF=['GALEX'] vs SCI=['SWIFT']
#    2007sw: REF=['GALEX'] vs SCI=['PS1']
#    2007uy: REF=['GALEX'] vs SCI=['SWIFT']
#    2008am: REF=['GALEX'] vs SCI=['SWIFT']
#    2008au: REF=['GALEX'] vs SCI=['PS1']
#    2008aw: REF=['GALEX'] vs SCI=['SWIFT']
#    2008bg: REF=['GALEX'] vs SCI=['PS1']
#    2008bn: REF=['GALEX'] vs SCI=['PS1']
#    2008cj: REF=['GALEX'] vs SCI=['PS1']
#    2008dq: REF=['GALEX'] vs SCI=['SWIFT']
#    2008ew: REF=['GALEX'] vs SCI=['PS1']
#    2008fj: REF=['GALEX'] vs SCI=['PS1']
#    2008fr: REF=['GALEX'] vs SCI=['PS1']
#    2008gn: REF=['GALEX'] vs SCI=['PS1']
#    2008hd: REF=['GALEX'] vs SCI=['PS1']
#    2008hr: REF=['GALEX'] vs SCI=['PS1']
#    2008hz: REF=['GALEX'] vs SCI=['PS1', 'SWIFT']
#    2009E: REF=['GALEX'] vs SCI=['PS1']
#    2009ae: REF=['GALEX'] vs SCI=['PS1']
#    2009an: REF=['GALEX'] vs SCI=['SWIFT']
#    2009bz: REF=['GALEX'] vs SCI=['PS1']
#    2009cn: REF=['GALEX'] vs SCI=['PS1']
#    2009db: REF=['GALEX'] vs SCI=['PS1']
#    2009dd: REF=['GALEX'] vs SCI=['SWIFT']
#    2009dg: REF=['GALEX'] vs SCI=['PS1']
#    2009en: REF=['GALEX'] vs SCI=['PS1']
#    2009et: REF=['GALEX'] vs SCI=['PS1']
#    2009eu: REF=['GALEX'] vs SCI=['PS1']
#    2009ey: REF=['GALEX'] vs SCI=['PS1']
#    2009ez: REF=['GALEX'] vs SCI=['PS1']
#    2009fh: REF=['GALEX'] vs SCI=['PS1']
#    2009fp: REF=['GALEX'] vs SCI=['PS1']
#    2009gm: REF=['GALEX'] vs SCI=['PS1']
#    2009go: REF=['GALEX'] vs SCI=['PS1']
#    2009hq: REF=['GALEX'] vs SCI=['PS1']
#    2009iq: REF=['GALEX'] vs SCI=['PS1', 'SWIFT']
#    2009ix: REF=['GALEX'] vs SCI=['PS1']
#    2009jb: REF=['SWIFT'] vs SCI=['PS1']
#    2009ji: REF=['SWIFT'] vs SCI=['PS1']
#    2009kd: REF=['SWIFT'] vs SCI=['PS1']
#    2009kh: REF=['GALEX'] vs SCI=['PS1']
#    2009kj: REF=['GALEX'] vs SCI=['PS1']
#    2009ku: REF=['GALEX'] vs SCI=['PS1']
#    2009mb: REF=['GALEX'] vs SCI=['PS1']
#    2009nm: REF=['GALEX'] vs SCI=['PS1']

# %% [markdown]
# ## 2. Helper Functions for Visualization

# %%
def load_fits_image(filepath: Path) -> tuple:
    """
    Load FITS image data and header info.
    Returns: (image_data, info_dict) or (None, error_info)
    """
    try:
        with fits.open(filepath) as hdul:
            # Try primary HDU first
            data = hdul[0].data
            header = hdul[0].header
            
            # If primary is empty, try first extension with data
            if data is None:
                for i, hdu in enumerate(hdul):
                    if hdu.data is not None and len(hdu.data.shape) >= 2:
                        data = hdu.data
                        header = hdu.header
                        break
            
            if data is None:
                return None, {'error': 'No image data found'}
            
            # Handle 3D data (take first slice)
            if len(data.shape) == 3:
                data = data[0]
            
            # Get WCS info
            try:
                wcs = WCS(header, naxis=2)
                has_wcs = wcs.has_celestial
            except Exception:
                has_wcs = False
            
            info = {
                'shape': data.shape,
                'dtype': str(data.dtype),
                'min': float(np.nanmin(data)),
                'max': float(np.nanmax(data)),
                'mean': float(np.nanmean(data)),
                'has_wcs': has_wcs,
                'filter': header.get('FILTER', header.get('FILTER1', 'unknown')),
                'exptime': header.get('EXPTIME', header.get('EXPOSURE', 'unknown')),
                'date_obs': header.get('DATE-OBS', 'unknown'),
            }
            
            return data.astype(float), info
            
    except Exception as e:
        return None, {'error': str(e)}


def display_image(ax, data: np.ndarray, title: str = "", cmap: str = 'gray'):
    """Display astronomical image with appropriate scaling."""
    if data is None:
        ax.text(0.5, 0.5, 'No data', ha='center', va='center', fontsize=12)
        ax.set_title(title)
        return
    
    # Use ZScale for astronomical images
    try:
        interval = ZScaleInterval()
        vmin, vmax = interval.get_limits(data[np.isfinite(data)])
    except Exception:
        vmin, vmax = np.nanpercentile(data, [1, 99])
    
    im = ax.imshow(data, origin='lower', cmap=cmap, vmin=vmin, vmax=vmax)
    ax.set_title(title, fontsize=10)
    plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)


def show_ref_sci_comparison(sn_name: str, ref_file: str, sci_file: str, base_dir: Path):
    """Display reference and science images side by side."""
    ref_path = base_dir / ref_file
    sci_path = base_dir / sci_file
    
    ref_data, ref_info = load_fits_image(ref_path)
    sci_data, sci_info = load_fits_image(sci_path)
    
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    fig.suptitle(f"SN {sn_name}", fontsize=14, fontweight='bold')
    
    # Reference
    ref_title = f"Reference\n{Path(ref_file).name[:40]}...\nShape: {ref_info.get('shape', 'N/A')}"
    display_image(axes[0], ref_data, ref_title)
    
    # Science
    sci_title = f"Science\n{Path(sci_file).name[:40]}...\nShape: {sci_info.get('shape', 'N/A')}"
    display_image(axes[1], sci_data, sci_title)
    
    # Simple difference (if same shape)
    if ref_data is not None and sci_data is not None:
        if ref_data.shape == sci_data.shape:
            diff = sci_data - ref_data
            display_image(axes[2], diff, "Simple Difference\n(Science - Reference)", cmap='RdBu_r')
        else:
            axes[2].text(0.5, 0.5, f"Shape mismatch\nRef: {ref_data.shape}\nSci: {sci_data.shape}", 
                        ha='center', va='center', fontsize=10)
            axes[2].set_title("Cannot difference")
    else:
        axes[2].text(0.5, 0.5, 'Missing data', ha='center', va='center')
        axes[2].set_title("Cannot difference")
    
    plt.tight_layout()
    plt.show()
    
    # Print metadata
    print(f"\nMetadata:")
    print(f"   Reference: filter={ref_info.get('filter')}, exptime={ref_info.get('exptime')}, WCS={ref_info.get('has_wcs')}")
    print(f"   Science:   filter={sci_info.get('filter')}, exptime={sci_info.get('exptime')}, WCS={sci_info.get('has_wcs')}")
    print(f"   Date (sci): {sci_info.get('date_obs')}")

print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## 3. Inspect Same-Mission Pairs
#
# Let's look at the SNe that have matching missions in reference and science.

# %%
# Get detailed info for same-mission SNe
print("=" * 60)
print("SAME-MISSION SNe - DETAILED VIEW")
print("=" * 60)

for analysis in same_mission_sne:
    sn = analysis['sn_name']
    print(f"\n🌟 {sn}")
    
    for mission in analysis['common_missions']:
        ref_files = analysis['ref_missions'].get(mission, [])
        sci_files = analysis['sci_missions'].get(mission, [])
        
        print(f"   📡 {mission}:")
        print(f"      Reference files: {len(ref_files)}")
        print(f"      Science files:   {len(sci_files)}")
        
        # Show filter breakdown for SWIFT
        if mission == "SWIFT":
            ref_filters = [get_swift_filter(f) for f in ref_files]
            sci_filters = [get_swift_filter(f) for f in sci_files]
            print(f"      Ref filters:  {sorted(set(ref_filters))}")
            print(f"      Sci filters:  {sorted(set(sci_filters))}")
            
            # Find matching filters
            common_filters = set(ref_filters) & set(sci_filters)
            if common_filters:
                print(f"      ✅ Matching filters: {sorted(common_filters)}")
# Out:
# ============================================================
# SAME-MISSION SNe - DETAILED VIEW
# ============================================================
#
# 🌟 2005V
#    📡 GALEX:
#       Reference files: 6
#       Science files:   6
#
# 🌟 2005ai
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2005ay
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 2005az
#    📡 GALEX:
#       Reference files: 3
#       Science files:   9
#
# 🌟 2005bj
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2005bk
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2005bn
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2005bt
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2005ca
#    📡 GALEX:
#       Reference files: 6
#       Science files:   6
#
# 🌟 2005cc
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2005ck
#    📡 GALEX:
#       Reference files: 3
#       Science files:   9
#
# 🌟 2005cr
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2005ct
#    📡 GALEX:
#       Reference files: 6
#       Science files:   6
#
# 🌟 2005dh
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 2005dn
#    📡 GALEX:
#       Reference files: 3
#       Science files:   9
#
# 🌟 2005dq
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2005dt
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2005dy
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2005ea
#    📡 GALEX:
#       Reference files: 6
#       Science files:   2
#
# 🌟 2005eb
#    📡 GALEX:
#       Reference files: 3
#       Science files:   6
#
# 🌟 2005ej
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2005eu
#    📡 GALEX:
#       Reference files: 9
#       Science files:   6
#
# 🌟 2005ev
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2005hh
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2005kl
#    📡 GALEX:
#       Reference files: 9
#       Science files:   3
#
# 🌟 2005lt
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2005lx
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2005mf
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2005mr
#    📡 GALEX:
#       Reference files: 9
#       Science files:   6
#
# 🌟 2005nc
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       Sci filters:  ['uvv', 'uwh']
#       ✅ Matching filters: ['uvv']
#
# 🌟 2006P
#    📡 GALEX:
#       Reference files: 3
#       Science files:   9
#
# 🌟 2006X
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['unknown', 'uvv']
#       Sci filters:  ['ubb', 'unknown', 'uvv']
#       ✅ Matching filters: ['unknown', 'uvv']
#
# 🌟 2006Z
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006af
#    📡 GALEX:
#       Reference files: 6
#       Science files:   6
#
# 🌟 2006ao
#    📡 GALEX:
#       Reference files: 3
#       Science files:   9
#
# 🌟 2006aq
#    📡 GALEX:
#       Reference files: 6
#       Science files:   6
#
# 🌟 2006as
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006ax
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006ay
#    📡 GALEX:
#       Reference files: 6
#       Science files:   6
#
# 🌟 2006bk
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006br
#    📡 GALEX:
#       Reference files: 3
#       Science files:   9
#
# 🌟 2006bt
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006by
#    📡 GALEX:
#       Reference files: 9
#       Science files:   3
#
# 🌟 2006ce
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006cg
#    📡 GALEX:
#       Reference files: 9
#       Science files:   6
#
# 🌟 2006cj
#    📡 GALEX:
#       Reference files: 6
#       Science files:   9
#
# 🌟 2006cs
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006ct
#    📡 GALEX:
#       Reference files: 6
#       Science files:   2
#
# 🌟 2006cx
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006da
#    📡 GALEX:
#       Reference files: 9
#       Science files:   3
#
# 🌟 2006db
#    📡 GALEX:
#       Reference files: 12
#       Science files:   6
#
# 🌟 2006dg
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006dh
#    📡 GALEX:
#       Reference files: 9
#       Science files:   3
#
# 🌟 2006di
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006dk
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006do
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006dq
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006dw
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006dy
#    📡 GALEX:
#       Reference files: 3
#       Science files:   6
#
# 🌟 2006dz
#    📡 GALEX:
#       Reference files: 3
#       Science files:   9
#
# 🌟 2006ec
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006em
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006et
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       Sci filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       ✅ Matching filters: ['ubb', 'unknown', 'uuu', 'uvv']
#
# 🌟 2006gi
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006gy
#    📡 SWIFT:
#       Reference files: 1
#       Science files:   5
#       Ref filters:  ['uvv']
#       Sci filters:  ['ubb', 'unknown', 'uvv']
#       ✅ Matching filters: ['uvv']
#
# 🌟 2006id
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006je
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006mo
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006mr
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       Sci filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       ✅ Matching filters: ['ubb', 'unknown', 'uuu', 'uvv']
#
# 🌟 2006ox
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006qs
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006qy
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 2006rk
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006rt
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006ry
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2006ss
#    📡 GALEX:
#       Reference files: 6
#       Science files:   6
#
# 🌟 2006st
#    📡 GALEX:
#       Reference files: 3
#       Science files:   6
#
# 🌟 2006su
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2006tf
#    📡 GALEX:
#       Reference files: 3
#       Science files:   9
#
# 🌟 2007ah
#    📡 SWIFT:
#       Reference files: 4
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu']
#       Sci filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       ✅ Matching filters: ['ubb', 'unknown', 'uuu']
#
# 🌟 2007am
#    📡 GALEX:
#       Reference files: 9
#       Science files:   6
#
# 🌟 2007ao
#    📡 GALEX:
#       Reference files: 5
#       Science files:   8
#
# 🌟 2007aq
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2007au
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2007av
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2007bf
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2007bh
#    📡 GALEX:
#       Reference files: 3
#       Science files:   6
#
# 🌟 2007cc
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2007ci
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2007cv
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['unknown', 'uuu']
#       Sci filters:  ['ubb', 'unknown', 'uvv']
#       ✅ Matching filters: ['unknown']
#
# 🌟 2007dd
#    📡 GALEX:
#       Reference files: 3
#       Science files:   9
#
# 🌟 2007de
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2007dh
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2007du
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2007dw
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2007eo
#    📡 GALEX:
#       Reference files: 9
#       Science files:   3
#
# 🌟 2007fy
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2007gr
#    📡 GALEX:
#       Reference files: 6
#       Science files:   9
#
# 🌟 2007hb
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2007hd
#    📡 GALEX:
#       Reference files: 3
#       Science files:   9
#
# 🌟 2007he
#    📡 GALEX:
#       Reference files: 6
#       Science files:   6
#
# 🌟 2007is
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2007mq
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2007oc
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       Sci filters:  ['ubb', 'unknown', 'uvv']
#       ✅ Matching filters: ['ubb', 'unknown', 'uvv']
#
# 🌟 2007qe
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2007rv
#    📡 GALEX:
#       Reference files: 9
#       Science files:   3
#
# 🌟 2007va
#    📡 GALEX:
#       Reference files: 8
#       Science files:   3
#
# 🌟 2008D
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu']
#       Sci filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       ✅ Matching filters: ['ubb', 'unknown', 'uuu']
#
# 🌟 2008S
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['unknown', 'uuu', 'uvv']
#       Sci filters:  ['unknown', 'uuu', 'uvv']
#       ✅ Matching filters: ['unknown', 'uuu', 'uvv']
#
# 🌟 2008X
#    📡 GALEX:
#       Reference files: 6
#       Science files:   3
#
# 🌟 2008bu
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2008ck
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2008dt
#    📡 SWIFT:
#       Reference files: 2
#       Science files:   5
#       Ref filters:  ['unknown', 'uuu']
#       Sci filters:  ['unknown', 'uuu']
#       ✅ Matching filters: ['unknown', 'uuu']
#
# 🌟 2008dx
#    📡 SWIFT:
#       Reference files: 1
#       Science files:   5
#       Ref filters:  ['ubb']
#       Sci filters:  ['ubb', 'unknown', 'uuu']
#       ✅ Matching filters: ['ubb']
#
# 🌟 2008fg
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['unknown', 'uvv']
#       Sci filters:  ['ubb', 'unknown', 'uuu']
#       ✅ Matching filters: ['unknown']
#
# 🌟 2008fh
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       Sci filters:  ['ubb', 'unknown', 'uvv']
#       ✅ Matching filters: ['ubb', 'unknown', 'uvv']
#
# 🌟 2008fo
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       Sci filters:  ['unknown', 'uuu', 'uvv']
#       ✅ Matching filters: ['unknown', 'uuu', 'uvv']
#
# 🌟 2008ij
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       Sci filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       ✅ Matching filters: ['ubb', 'unknown', 'uuu', 'uvv']
#
# 🌟 2008ik
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 2008iz
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['unknown']
#       Sci filters:  ['ubb', 'unknown', 'uuu']
#       ✅ Matching filters: ['unknown']
#
# 🌟 2009L
#    📡 GALEX:
#       Reference files: 8
#       Science files:   2
#
# 🌟 2009Y
#    📡 SWIFT:
#       Reference files: 2
#       Science files:   5
#       Ref filters:  ['unknown', 'uuu']
#       Sci filters:  ['unknown']
#       ✅ Matching filters: ['unknown']
#
# 🌟 2009be
#    📡 SWIFT:
#       Reference files: 1
#       Science files:   1
#       Ref filters:  ['unknown']
#       Sci filters:  ['uuu']
#
# 🌟 2009cb
#    📡 GALEX:
#       Reference files: 3
#       Science files:   3
#
# 🌟 2009gf
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['unknown', 'uuu', 'uvv']
#       Sci filters:  ['ubb', 'unknown', 'uuu']
#       ✅ Matching filters: ['unknown', 'uuu']
#
# 🌟 2009hd
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       Sci filters:  ['ubb', 'unknown', 'uuu']
#       ✅ Matching filters: ['ubb', 'unknown', 'uuu']
#
# 🌟 2009hk
#    📡 PS1:
#       Reference files: 1
#       Science files:   5
#
# 🌟 2009hl
#    📡 PS1:
#       Reference files: 1
#       Science files:   5
#
# 🌟 2009hz
#    📡 PS1:
#       Reference files: 5
#       Science files:   3
#
# 🌟 2009ih
#    📡 PS1:
#       Reference files: 4
#       Science files:   5
#
# 🌟 2009in
#    📡 PS1:
#       Reference files: 4
#       Science files:   5
#
# 🌟 2009io
#    📡 PS1:
#       Reference files: 4
#       Science files:   5
#
# 🌟 2009iu
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 2009jf
#    📡 SWIFT:
#       Reference files: 3
#       Science files:   5
#       Ref filters:  ['unknown']
#       Sci filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       ✅ Matching filters: ['unknown']
#
# 🌟 2009jp
#    📡 PS1:
#       Reference files: 5
#       Science files:   5
#
# 🌟 2009jq
#    📡 PS1:
#       Reference files: 2
#       Science files:   5
#
# 🌟 2009ka
#    📡 PS1:
#       Reference files: 2
#       Science files:   5
#
# 🌟 2009kc
#    📡 PS1:
#       Reference files: 2
#       Science files:   5
#
# 🌟 2009kr
#    📡 SWIFT:
#       Reference files: 2
#       Science files:   5
#       Ref filters:  ['unknown']
#       Sci filters:  ['ubb', 'unknown', 'uuu']
#       ✅ Matching filters: ['unknown']
#
# 🌟 2009kw
#    📡 PS1:
#       Reference files: 2
#       Science files:   5
#
# 🌟 2009ky
#    📡 PS1:
#       Reference files: 3
#       Science files:   5
#
# 🌟 2009ld
#    📡 PS1:
#       Reference files: 2
#       Science files:   5
#
# 🌟 2009le
#    📡 PS1:
#       Reference files: 1
#       Science files:   4
#
# 🌟 2009lg
#    📡 PS1:
#       Reference files: 1
#       Science files:   4
#
# 🌟 2009lo
#    📡 PS1:
#       Reference files: 1
#       Science files:   5
#
# 🌟 2009lw
#    📡 PS1:
#       Reference files: 2
#       Science files:   5
#
# 🌟 2009lz
#    📡 PS1:
#       Reference files: 1
#       Science files:   5
#
# 🌟 2009mg
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['ubb', 'unknown', 'uuu', 'uvv']
#       Sci filters:  ['unknown', 'uuu', 'uvv']
#       ✅ Matching filters: ['unknown', 'uuu', 'uvv']
#
# 🌟 2009ml
#    📡 PS1:
#       Reference files: 4
#       Science files:   5
#
# 🌟 2009nn
#    📡 PS1:
#       Reference files: 3
#       Science files:   5
#
# 🌟 2009no
#    📡 PS1:
#       Reference files: 2
#       Science files:   5
#
# 🌟 2009nr
#    📡 PS1:
#       Reference files: 4
#       Science files:   5
#
# 🌟 2009nx
#    📡 PS1:
#       Reference files: 2
#       Science files:   5
#
# 🌟 2009nz
#    📡 SWIFT:
#       Reference files: 5
#       Science files:   5
#       Ref filters:  ['unknown', 'uuu', 'uvv', 'uwh']
#       Sci filters:  ['uwh']
#       ✅ Matching filters: ['uwh']
#
# 🌟 2010G
#    📡 PS1:
#       Reference files: 2
#       Science files:   5
#
# 🌟 2010N
#    📡 PS1:
#       Reference files: 2
#       Science files:   5
#
# 🌟 2010R
#    📡 PS1:
#       Reference files: 4
#       Science files:   5
#
# 🌟 2010bb
#    📡 PS1:
#       Reference files: 2
#       Science files:   3
#
# 🌟 2010bc
#    📡 PS1:
#       Reference files: 5
#       Science files:   5
#
# 🌟 HST05Dic
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 HST05Fer
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 HST05Gab
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 HST05Koe
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 HST05Lan
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 HST05Red
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 HST05Spo
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 HST05Str
#    📡 GALEX:
#       Reference files: 9
#       Science files:   9
#
# 🌟 HST05Zwi
#    📡 GALEX:
#       Reference files: 9
#       Science files:   8

# %% [markdown]
# ## 4. Visual Inspection: Pick a SN to Examine
#
# Select a supernova with same-mission data and visually compare reference vs science.

# %%
# Pick a SN to inspect
TARGET_SN = "2014J"

# Find it in manifest
target_entry = next((e for e in manifest if e['sn_name'] == TARGET_SN), None)
target_analysis = next((a for a in analyses if a['sn_name'] == TARGET_SN), None)

if target_entry is None:
    print(f"❌ SN {TARGET_SN} not found in manifest")
else:
    print(f"✅ Found SN {TARGET_SN}")
    print(f"   Reference files: {len(target_entry['reference_files'])}")
    print(f"   Science files: {len(target_entry['science_files'])}")
    print(f"   Common missions: {target_analysis['common_missions']}")
# Out:
# ❌ SN 2014J not found in manifest

# %%
# List available files for the target SN
if target_entry:
    print(f"\nReference files for {TARGET_SN}:")
    for i, f in enumerate(target_entry['reference_files'][:10]):
        filt = get_swift_filter(f) if 'SWIFT' in f else 'N/A'
        print(f"   [{i}] {Path(f).name} (filter: {filt})")
    if len(target_entry['reference_files']) > 10:
        print(f"   ... and {len(target_entry['reference_files']) - 10} more")
    
    print(f"\nScience files for {TARGET_SN}:")
    for i, f in enumerate(target_entry['science_files']):
        filt = get_swift_filter(f) if 'SWIFT' in f else 'N/A'
        print(f"   [{i}] {Path(f).name} (filter: {filt})")

# %%
# Compare a reference and science image with MATCHING filter
if target_entry and target_analysis['has_same_mission_pair']:
    # Find matching filter pair
    ref_files = target_entry['reference_files']
    sci_files = target_entry['science_files']
    
    # Group by filter
    ref_by_filter = defaultdict(list)
    sci_by_filter = defaultdict(list)
    
    for f in ref_files:
        if 'SWIFT' in f:
            filt = get_swift_filter(f)
            ref_by_filter[filt].append(f)
    
    for f in sci_files:
        if 'SWIFT' in f:
            filt = get_swift_filter(f)
            sci_by_filter[filt].append(f)
    
    # Find common filters
    common_filters = set(ref_by_filter.keys()) & set(sci_by_filter.keys())
    print(f"Common SWIFT filters: {sorted(common_filters)}")
    
    # Pick first common filter and show comparison
    if common_filters:
        chosen_filter = sorted(common_filters)[0]
        ref_file = ref_by_filter[chosen_filter][0]
        sci_file = sci_by_filter[chosen_filter][0]
        
        print(f"\nComparing {chosen_filter} filter images:")
        show_ref_sci_comparison(TARGET_SN, ref_file, sci_file, TRAINING_DIR)

# %%
# ISSUE IDENTIFIED: Need to match filters AND align via WCS!
# The previous comparison used different filters (uw1 vs um2) - wrong!
# Let's do a proper same-filter comparison with WCS alignment

from reproject import reproject_interp

def show_aligned_comparison(sn_name: str, ref_file: str, sci_file: str, base_dir: Path):
    """Display WCS-aligned reference and science images."""
    ref_path = base_dir / ref_file
    sci_path = base_dir / sci_file
    
    # Load with full header for WCS
    with fits.open(ref_path) as hdul:
        for hdu in hdul:
            if hdu.data is not None and len(hdu.data.shape) >= 2:
                ref_data = hdu.data.astype(float)
                ref_header = hdu.header
                if len(ref_data.shape) == 3:
                    ref_data = ref_data[0]
                break
    
    with fits.open(sci_path) as hdul:
        for hdu in hdul:
            if hdu.data is not None and len(hdu.data.shape) >= 2:
                sci_data = hdu.data.astype(float)
                sci_header = hdu.header
                if len(sci_data.shape) == 3:
                    sci_data = sci_data[0]
                break
    
    ref_wcs = WCS(ref_header, naxis=2)
    sci_wcs = WCS(sci_header, naxis=2)
    
    print(f"Reference: {Path(ref_file).name}")
    print(f"  Date: {ref_header.get('DATE-OBS', 'N/A')}")
    print(f"  Shape: {ref_data.shape}")
    
    print(f"\nScience: {Path(sci_file).name}")
    print(f"  Date: {sci_header.get('DATE-OBS', 'N/A')}")
    print(f"  Shape: {sci_data.shape}")
    
    # Reproject science to match reference WCS
    print("\n🔄 Reprojecting science image to match reference WCS...")
    sci_reproj, footprint = reproject_interp(
        (sci_data, sci_wcs), 
        ref_header, 
        shape_out=ref_data.shape
    )
    
    # Compute difference
    diff = sci_reproj - ref_data
    
    # Handle NaN from reprojection (areas outside overlap)
    diff[~np.isfinite(diff)] = 0
    sci_reproj[~np.isfinite(sci_reproj)] = np.nan
    
    # Display
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    fig.suptitle(f"SN {sn_name} - WCS Aligned (Same Filter)", fontsize=14, fontweight='bold')
    
    # Reference
    interval = ZScaleInterval()
    vmin, vmax = interval.get_limits(ref_data[np.isfinite(ref_data)])
    im1 = axes[0].imshow(ref_data, origin='lower', cmap='gray', vmin=vmin, vmax=vmax)
    axes[0].set_title(f"Reference (PRE-SN)\n{ref_header.get('DATE-OBS', '')[:10]}")
    plt.colorbar(im1, ax=axes[0], fraction=0.046)
    
    # Science (reprojected)
    vmin2, vmax2 = interval.get_limits(sci_reproj[np.isfinite(sci_reproj)])
    im2 = axes[1].imshow(sci_reproj, origin='lower', cmap='gray', vmin=vmin2, vmax=vmax2)
    axes[1].set_title(f"Science (POST-SN)\n{sci_header.get('DATE-OBS', '')[:10]}")
    plt.colorbar(im2, ax=axes[1], fraction=0.046)
    
    # Difference
    vmax_diff = np.nanpercentile(np.abs(diff), 99)
    im3 = axes[2].imshow(diff, origin='lower', cmap='RdBu_r', vmin=-vmax_diff, vmax=vmax_diff)
    axes[2].set_title("Difference\n(Science - Reference)")
    plt.colorbar(im3, ax=axes[2], fraction=0.046)
    
    # Footprint (overlap region)
    axes[3].imshow(footprint, origin='lower', cmap='gray')
    axes[3].set_title("Overlap Footprint")
    
    plt.tight_layout()
    plt.show()
    
    return diff, footprint

print("✅ WCS-aligned comparison function ready")
# Out:
# ✅ WCS-aligned comparison function ready

# %%
# Now compare with MATCHING filter (uvv) and WCS alignment 

# Find files containing "uvv" in the reference and science folders
ref_dir = TRAINING_DIR / TARGET_SN / "reference"
sci_dir = TRAINING_DIR / TARGET_SN / "science"

ref_uvv_files = list(ref_dir.glob("*uvv*.fits"))
sci_uvv_files = list(sci_dir.glob("*uvv*.fits"))

if ref_uvv_files and sci_uvv_files:
    # Use the first match from each folder, convert to relative path
    ref_uvv = str(ref_uvv_files[0].relative_to(TRAINING_DIR))
    sci_uvv = str(sci_uvv_files[0].relative_to(TRAINING_DIR))
    
    print("🔬 SN "+TARGET_SN+" - Proper same-filter (uvv) WCS-aligned comparison")
    print("=" * 60)
    print(f"Reference: {ref_uvv}")
    print(f"Science: {sci_uvv}")
    diff_result, footprint = show_aligned_comparison(TARGET_SN, ref_uvv, sci_uvv, TRAINING_DIR)
else:
    print(f"⚠️ No uvv filter files found for {TARGET_SN}")
    if not ref_uvv_files:
        print(f"   Missing in reference folder")
    if not sci_uvv_files:
        print(f"   Missing in science folder")
# Out:
# ⚠️ No uvv filter files found for 2014J
#    Missing in reference folder
#    Missing in science folder

# %%
# Also try the uuu filter pair
ref_dir = TRAINING_DIR / TARGET_SN / "reference"
sci_dir = TRAINING_DIR / TARGET_SN / "science"

ref_uuu_files = list(ref_dir.glob("*uuu*.fits"))
sci_uuu_files = list(sci_dir.glob("*uuu*.fits"))

if ref_uuu_files and sci_uuu_files:
    # Use the first match from each folder, convert to relative path
    ref_uuu = str(ref_uuu_files[0].relative_to(TRAINING_DIR))
    sci_uuu = str(sci_uuu_files[0].relative_to(TRAINING_DIR))
    
    print("🔬 SN "+TARGET_SN+" - Proper same-filter (uuu) WCS-aligned comparison")
    print("=" * 60)
    print(f"Reference: {ref_uuu}")
    print(f"Science: {sci_uuu}")
    diff_result, footprint = show_aligned_comparison(TARGET_SN, ref_uuu, sci_uuu, TRAINING_DIR)
else:
    print(f"⚠️ No uuu filter files found for {TARGET_SN}")
    if not ref_uuu_files:
        print(f"   Missing in reference folder")
    if not sci_uuu_files:
        print(f"   Missing in science folder")
# Out:
# ⚠️ No uuu filter files found for 2014J
#    Missing in reference folder
#    Missing in science folder

# %% [markdown]
# ## 7. Full Differencing Pipeline
#
# A reusable pipeline with:
# 1. WCS alignment (reprojection)
# 2. Background estimation and subtraction
# 3. PSF estimation and matching
# 4. Flux normalization
# 5. ZOGY optimal differencing
# 6. Source detection on difference image
# 7. Known SN position marking

# %%
# Import from shared module
from src.domains.differencing.pipeline import (
    DifferencingResult as PipelineResult,
    SNDifferencingPipeline,
)

# Create wrapper for notebook visualization (preserves images)
def process_with_images(pipeline, ref_path, sci_path, sn_name="unknown", sn_coords=None):
    """Wrapper that preserves image arrays for visualization."""
    diff, sig, mask, result = pipeline.process(ref_path, sci_path, sn_name, sn_coords)
    
    # Reload images (pipeline cleans them up)
    ref_data, ref_header, ref_wcs = pipeline.load_fits(ref_path)
    sci_data, sci_header, sci_wcs = pipeline.load_fits(sci_path)
    
    # Reproject for visualization
    from reproject import reproject_interp
    sci_aligned, footprint = reproject_interp(
        (sci_data, sci_wcs), ref_wcs, shape_out=ref_data.shape
    )
    
    # Return dict compatible with your visualization function
    return {
        'sn_name': result.sn_name,
        'filter_name': result.filter_name,
        'reference': ref_data,
        'science': sci_data,
        'science_aligned': sci_aligned,
        'difference': diff,
        'significance': sig,
        'footprint': footprint,
        'ref_header': ref_header,
        'sci_header': sci_header,
        'metrics': {
            'overlap_fraction': result.overlap_fraction,
            'sig_max': result.sig_max,
            # ... other metrics
        },
        'sn_pixel': result.sn_pixel,
    }
# Out:
# INFO:src.core.db.session:No SSL certificate path provided, using certifi CA bundle
# INFO:src.core.db.session:Using certifi CA bundle for SSL verification
# INFO:src.core.db.session:Creating database engine with URL: postgresql+asyncpg://postgres:None@aws-0-us-west-1.pooler.supabase.com:5432/postgres
# INFO:src.core.db.session:Database engine created successfully
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Import from shared module
# ----> 2 from src.domains.differencing.pipeline import (
#       3     DifferencingResult as PipelineResult,
#       4     SNDifferencingPipeline,
#       5 )
#       7 # Create wrapper for notebook visualization (preserves images)
#       8 def process_with_images(pipeline, ref_path, sci_path, sn_name="unknown", sn_coords=None):
#
# File /mnt/astrid/AstrID/src/domains/differencing/__init__.py:3
#       1 """Differencing domain module."""
# ----> 3 from . import crud, models, repository, schema, service
#       4 from .api import routes
#       6 __all__ = ["models", "schema", "crud", "service", "repository", "routes"]
#
# File /mnt/astrid/AstrID/src/domains/differencing/crud.py:11
#       8 from sqlalchemy.ext.asyncio import AsyncSession
#      10 from src.core.db.exceptions import create_db_error
# ---> 11 from src.domains.differencing.models import Candidate, DifferenceRun
#      12 from src.domains.differencing.schema import (
#      13     CandidateCreate,
#      14     CandidateListParams,
#    (...)     18     DifferenceRunUpdate,
#      19 )
#      22 class DifferenceRunCRUD:
#
# File /mnt/astrid/AstrID/src/domains/differencing/models.py:23
#      20 from sqlalchemy.orm import Mapped, mapped_column, relationship
#      22 from src.core.db.session import Base
# ---> 23 from src.domains.observations.models import Observation
#      26 class DifferenceRunStatus(str, Enum):
#      27     """Difference run status."""
#
# File /mnt/astrid/AstrID/src/domains/observations/__init__.py:3
#       1 """Observations domain module."""
# ----> 3 from . import crud, models, repository, schema, service
#       4 from .api import routes
#       6 __all__ = ["models", "schema", "crud", "service", "repository", "routes"]
#
# File /mnt/astrid/AstrID/src/domains/observations/service.py:17
#      12 from src.domains.observations.crud import ObservationCRUD, SurveyCRUD
#      13 from src.domains.observations.events import (
#      14     ObservationFailed,
#      15     ObservationStatusChanged,
#      16 )
# ---> 17 from src.domains.observations.ingestion.services import (
#      18     DataIngestionService,
#      19     ObservationBuilderService,
#      20 )
#      21 from src.domains.observations.schema import (
#      22     ObservationCreate,
#      23     ObservationListParams,
#    (...)     30     SurveyUpdate,
#      31 )
#      32 from src.domains.observations.validators import (
#      33     ObservationValidationError,
#      34     ObservationValidator,
#      35 )
#
# File /mnt/astrid/AstrID/src/domains/observations/ingestion/__init__.py:3
#       1 """Data ingestion module for observations domain."""
# ----> 3 from . import processors, services
#       5 __all__ = ["processors", "services"]
#
# File /mnt/astrid/AstrID/src/domains/observations/ingestion/services/__init__.py:3
#       1 """Ingestion services for observations domain."""
# ----> 3 from .data_ingestion import DataIngestionService
#       4 from .observation_builder import ObservationBuilderService
#       6 __all__ = ["DataIngestionService", "ObservationBuilderService"]
#
# File /mnt/astrid/AstrID/src/domains/observations/ingestion/services/data_ingestion.py:22
#      20 from src.domains.observations.schema import ObservationCreate
#      21 from src.domains.observations.survey_config import SurveyConfigurationRead
# ---> 22 from src.domains.observations.survey_config_service import SurveyConfigurationService
#      23 from src.infrastructure.storage.config import StorageConfig
#      24 from src.infrastructure.storage.r2_client import R2StorageClient
#
# File /mnt/astrid/AstrID/src/domains/observations/survey_config_service.py:9
#       6 from sqlalchemy.ext.asyncio import AsyncSession
#       8 from src.core.logging import configure_domain_logger
# ----> 9 from src.domains.catalog.models import SystemConfig
#      10 from src.domains.observations.survey_config import (
#      11     DEFAULT_SURVEY_CONFIGURATIONS,
#      12     SurveyConfiguration,
#    (...)     15     SurveyConfigurationUpdate,
#      16 )
#      19 class SurveyConfigurationService:
#
# File /mnt/astrid/AstrID/src/domains/catalog/__init__.py:4
#       1 """Catalog domain module."""
#       3 from . import crud, models, repository, schema, service
# ----> 4 from .api import routes
#       6 __all__ = ["models", "schema", "crud", "service", "repository", "routes"]
#
# File /mnt/astrid/AstrID/src/domains/catalog/api/routes.py:6
#       3 from fastapi import APIRouter, Depends, HTTPException, Query
#       4 from pydantic import BaseModel
# ----> 6 from src.adapters.auth.rbac import (
#       7     Permission,
#       8     UserWithRole,
#       9     require_permission,
#      10 )
#      11 from src.core.api.response_wrapper import ResponseEnvelope, create_response
#      12 from src.core.db.session import get_db
#
# File /mnt/astrid/AstrID/src/adapters/auth/rbac.py:9
#       6 from fastapi import Depends, HTTPException, status
#       7 from pydantic import BaseModel
# ----> 9 from src.adapters.auth.supabase_auth import User, get_current_user
#      11 logger = logging.getLogger(__name__)
#      14 class Role(str, Enum):
#
# File /mnt/astrid/AstrID/src/adapters/auth/supabase_auth.py:213
#     206             raise HTTPException(
#     207                 status_code=status.HTTP_400_BAD_REQUEST,
#     208                 detail="Failed to update user metadata",
#     209             ) from e
#     212 # Global auth service instance
# --> 213 auth_service = AuthService()
#     216 async def get_current_user(
#     217     credentials: HTTPAuthorizationCredentials = Depends(security),
#     218 ) -> User:
#     219     """Dependency to get current authenticated user."""
#
# File /mnt/astrid/AstrID/src/adapters/auth/supabase_auth.py:55, in AuthService.__init__(self)
#      54 def __init__(self) -> None:
# ---> 55     self.client = get_supabase_client()
#      56     self.jwt_secret = SUPABASE_JWT_SECRET
#
# File /mnt/astrid/AstrID/src/adapters/auth/supabase_auth.py:33, in get_supabase_client()
#      31 if supabase is None:
#      32     if not SUPABASE_URL or not SUPABASE_KEY:
# ---> 33         raise ValueError("Supabase URL and anon key must be configured")
#      34     supabase = create_client(SUPABASE_URL, SUPABASE_KEY)
#      35 return supabase
#
# ValueError: Supabase URL and anon key must be configured

# %%
def visualize_result(result: DifferencingResult, figsize=(20, 10)):
    """
    Visualize differencing pipeline results.
    
    Shows: Reference, Science (aligned), Difference, Significance
    With SN position marked if known.
    """
    fig, axes = plt.subplots(2, 4, figsize=figsize)
    fig.suptitle(f"SN {result.sn_name} - {result.filter_name} filter\n"
                 f"Ref: {result.ref_header.get('DATE-OBS', '')[:10]} | "
                 f"Sci: {result.sci_header.get('DATE-OBS', '')[:10]}", 
                 fontsize=14, fontweight='bold')
    
    interval = ZScaleInterval()
    valid = result.footprint > 0.5
    
    # Row 1: Images
    # Reference
    vmin, vmax = interval.get_limits(result.reference[np.isfinite(result.reference)])
    im1 = axes[0, 0].imshow(result.reference, origin='lower', cmap='gray', vmin=vmin, vmax=vmax)
    axes[0, 0].set_title("Reference (PRE-SN)")
    plt.colorbar(im1, ax=axes[0, 0], fraction=0.046)
    
    # Science aligned
    vmin2, vmax2 = interval.get_limits(result.science_aligned[valid])
    im2 = axes[0, 1].imshow(result.science_aligned, origin='lower', cmap='gray', vmin=vmin2, vmax=vmax2)
    axes[0, 1].set_title("Science Aligned (POST-SN)")
    plt.colorbar(im2, ax=axes[0, 1], fraction=0.046)
    
    # Difference
    vmax_diff = np.nanpercentile(np.abs(result.difference[valid]), 99)
    im3 = axes[0, 2].imshow(result.difference, origin='lower', cmap='RdBu_r', 
                            vmin=-vmax_diff, vmax=vmax_diff)
    axes[0, 2].set_title("Difference (Sci - Ref)")
    plt.colorbar(im3, ax=axes[0, 2], fraction=0.046)
    
    # Significance
    vmax_sig = min(np.nanpercentile(np.abs(result.significance[valid]), 99.5), 20)
    im4 = axes[0, 3].imshow(result.significance, origin='lower', cmap='RdBu_r',
                            vmin=-vmax_sig, vmax=vmax_sig)
    axes[0, 3].set_title(f"Significance (σ)\nMax: {result.metrics['sig_max']:.1f}σ")
    plt.colorbar(im4, ax=axes[0, 3], fraction=0.046)
    
    # Mark SN position on all plots
    if result.sn_pixel is not None:
        x, y = result.sn_pixel
        for ax in axes[0, :]:
            ax.scatter([x], [y], marker='o', s=200, facecolors='none', 
                      edgecolors='lime', linewidths=2, label='Known SN')
            ax.scatter([x], [y], marker='+', s=100, c='lime', linewidths=2)
    
    # Row 2: Diagnostics
    # Footprint
    axes[1, 0].imshow(result.footprint, origin='lower', cmap='gray')
    axes[1, 0].set_title(f"Overlap Footprint\n{result.metrics['overlap_fraction']:.1f}%")
    
    # Histogram of significance
    sig_vals = result.significance[valid].flatten()
    sig_vals = sig_vals[np.isfinite(sig_vals)]
    axes[1, 1].hist(sig_vals, bins=100, range=(-10, 10), density=True, alpha=0.7)
    axes[1, 1].axvline(0, color='k', linestyle='--', alpha=0.5)
    axes[1, 1].axvline(5, color='r', linestyle='--', alpha=0.5, label='5σ')
    axes[1, 1].axvline(-5, color='r', linestyle='--', alpha=0.5)
    axes[1, 1].set_xlabel("Significance (σ)")
    axes[1, 1].set_ylabel("Density")
    axes[1, 1].set_title("Significance Distribution")
    axes[1, 1].legend()
    
    # Zoomed difference around SN (if known)
    if result.sn_pixel is not None:
        x, y = result.sn_pixel
        x, y = int(x), int(y)
        size = 100
        y1, y2 = max(0, y-size), min(result.difference.shape[0], y+size)
        x1, x2 = max(0, x-size), min(result.difference.shape[1], x+size)
        
        cutout = result.difference[y1:y2, x1:x2]
        vmax_cut = np.nanpercentile(np.abs(cutout), 99)
        im5 = axes[1, 2].imshow(cutout, origin='lower', cmap='RdBu_r',
                                vmin=-vmax_cut, vmax=vmax_cut)
        axes[1, 2].scatter([size], [size], marker='+', s=200, c='lime', linewidths=2)
        axes[1, 2].set_title(f"Zoomed Difference\n(200x200 px around SN)")
        plt.colorbar(im5, ax=axes[1, 2], fraction=0.046)
        
        # Zoomed significance
        cutout_sig = result.significance[y1:y2, x1:x2]
        vmax_sig_cut = min(np.nanpercentile(np.abs(cutout_sig), 99), 15)
        im6 = axes[1, 3].imshow(cutout_sig, origin='lower', cmap='RdBu_r',
                                vmin=-vmax_sig_cut, vmax=vmax_sig_cut)
        axes[1, 3].scatter([size], [size], marker='+', s=200, c='lime', linewidths=2)
        axes[1, 3].set_title("Zoomed Significance")
        plt.colorbar(im6, ax=axes[1, 3], fraction=0.046)
    else:
        axes[1, 2].text(0.5, 0.5, "No SN coords\nprovided", ha='center', va='center')
        axes[1, 3].text(0.5, 0.5, "No SN coords\nprovided", ha='center', va='center')
    
    plt.tight_layout()
    plt.show()
    
    # Print metrics
    print("\n📊 Pipeline Metrics:")
    for key, val in result.metrics.items():
        print(f"   {key}: {val:.4f}" if isinstance(val, float) else f"   {key}: {val}")

print("✅ Visualization function defined")

# %%
# Known SN coordinates from catalogs/literature
# With J2000 coordinates of RA = 6h 21m 44s.86 Dec. = −59°44′26″  - https://academic.oup.com/mnras/article/424/2/1297/999770
from astropy.coordinates import SkyCoord

SN_COORDINATES = {
    "2014J": SkyCoord("6h 21m 44.86s", "-59d 44m 26s", frame='icrs'),
    # Add more as we find them...
}

# Test the full pipeline on SN 2014J with the uuu filter
pipeline = SNDifferencingPipeline(
    psf_fwhm=4.0,  # SWIFT UVOT typical FWHM
    background_box_size=64,
    detection_threshold=5.0
)

# Process SN 2014J (uuu filter - best overlap)
ref_path = TRAINING_DIR / "2014J" / "reference" / "SWIFT_sw00031102001uuu_sk.fits"
sci_path = TRAINING_DIR / "2014J" / "science" / "SWIFT_sw00031562001uuu_sk.fits"

result_2014J = pipeline.process(
    ref_path=ref_path,
    sci_path=sci_path,
    sn_name="2014J",
    sn_coords=SN_COORDINATES.get("2014J")
)

# %%
# Visualize the results
visualize_result(result_2014J)

# %% [markdown]
# ## 8. Process All Same-Mission SNe
#
# Run the pipeline on all 8 SNe with SWIFT-SWIFT pairs.

# %%
def find_matching_filter_pair(sn_name: str, base_dir: Path) -> Optional[Tuple[Path, Path, str]]:
    """
    Find a reference/science pair with matching SWIFT filter.
    
    Returns:
        (ref_path, sci_path, filter_name) or None if no match
    """
    ref_dir = base_dir / sn_name / "reference"
    sci_dir = base_dir / sn_name / "science"
    
    if not ref_dir.exists() or not sci_dir.exists():
        return None
    
    # Get SWIFT files grouped by filter
    ref_by_filter = defaultdict(list)
    sci_by_filter = defaultdict(list)
    
    for f in ref_dir.glob("SWIFT_*.fits"):
        for filt in ['uvw2', 'uvm2', 'uvw1', 'uuu', 'ubb', 'uvv']:
            if filt in f.name.lower():
                ref_by_filter[filt].append(f)
                break
    
    for f in sci_dir.glob("SWIFT_*.fits"):
        for filt in ['uvw2', 'uvm2', 'uvw1', 'uuu', 'ubb', 'uvv']:
            if filt in f.name.lower():
                sci_by_filter[filt].append(f)
                break
    
    # Find common filters
    common = set(ref_by_filter.keys()) & set(sci_by_filter.keys())
    
    if not common:
        return None
    
    # Prefer uuu (U-band) or uvw1 for best SN visibility
    for preferred in ['uuu', 'uvw1', 'uvm2', 'uvw2', 'ubb', 'uvv']:
        if preferred in common:
            return ref_by_filter[preferred][0], sci_by_filter[preferred][0], preferred
    
    # Fallback to any common filter
    filt = list(common)[0]
    return ref_by_filter[filt][0], sci_by_filter[filt][0], filt

# List of same-mission SNe
SAME_MISSION_SNE = ['2013gc', '2013hh', '2013hn', '2014J', '2014L', '2014ai', '2014bh', '2014bi']

print(f"Processing {len(SAME_MISSION_SNE)} same-mission SNe...")
print("=" * 60)

# %%
# Process all same-mission SNe
# Set to True to run (takes a few minutes)
PROCESS_ALL = True

all_results = {}

if PROCESS_ALL:
    for sn_name in SAME_MISSION_SNE:
        print(f"\n{'='*60}")
        pair = find_matching_filter_pair(sn_name, TRAINING_DIR)
        
        if pair is None:
            print(f"⚠️  {sn_name}: No matching filter pair found")
            continue
        
        ref_path, sci_path, filter_name = pair
        print(f"📁 {sn_name}: Using {filter_name} filter")
        
        try:
            result = pipeline.process(
                ref_path=ref_path,
                sci_path=sci_path,
                sn_name=sn_name,
                sn_coords=SN_COORDINATES.get(sn_name)
            )
            all_results[sn_name] = result
            
            # Quick visualization
            visualize_result(result)
            
        except Exception as e:
            print(f"❌ {sn_name}: Processing failed - {e}")
            import traceback
            traceback.print_exc()
else:
    print("Set PROCESS_ALL = True to process all SNe")

# %% [markdown]
# ## 9. Save Pipeline for Reuse
#
# Export the pipeline class for use in other notebooks and scripts.

# %%
# Save results summary
if all_results or result_2014J:
    summary = {
        'pipeline_version': '1.0',
        'processed_sne': list(all_results.keys()) if all_results else ['2014J'],
        'results': {}
    }
    
    results_to_save = all_results if all_results else {'2014J': result_2014J}
    
    for sn_name, result in results_to_save.items():
        summary['results'][sn_name] = {
            'filter': result.filter_name,
            'ref_date': result.ref_header.get('DATE-OBS', 'N/A')[:10],
            'sci_date': result.sci_header.get('DATE-OBS', 'N/A')[:10],
            'metrics': result.metrics,
            'sn_pixel': result.sn_pixel,
        }
    
    output_file = TRAINING_DIR / 'differencing_results.json'
    with open(output_file, 'w') as f:
        json.dump(summary, f, indent=2, default=str)
    
    print(f"💾 Results saved to: {output_file}")

print("\n" + "=" * 60)
print("DIFFERENCING PIPELINE COMPLETE")
print("=" * 60)
print("""
✅ SNDifferencingPipeline ready!

Next: Run triplet generation below (Phase 4) to create CNN training data.
""")
